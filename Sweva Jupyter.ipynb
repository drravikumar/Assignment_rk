# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# #__RAVI KUMAR JUJJUVARAPU__
#
# Data Acientist

# %% [markdown]
# "_I am interested in Data Science because I am very passionate about learning new technology and also to use it for my engineering research_"

# %% [markdown]
# ### Hello World Program and Math operation

# %%
print ("Hello World")
s1 = int (1 + 1)
s2 = int (10 / 5)
addition = s1
division = s2
print (s1)
print (s2)
# Out:
# Hello World
# 2
# 2

# %%
## Basic Math operation using Python

****

@https://www.eenadu.net/

| Syntax      | Description | Test Text     |
| :---        |    :----:   |          ---: |
| Header      | Title       | Here's this   |
| Paragraph   | Text        | And more      |

strikethrough
